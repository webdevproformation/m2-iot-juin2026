# %% [markdown]
# les NDArray => Tableaux à N Dimensions
#
# tableau beaucoup plus puissant que les listes classique python / et prennent moins de place en mémoire que data structures (liste / dictionnaires)

# %%
import numpy as np

# créer des nd array à 1 dimension => vecteur
# créer des tableau à 2 dimensions => matrice 

tab1 = np.array([ 1,2,3 ])
tab1
# Out:
# array([1, 2, 3])

# %%
tab2 = np.array([
    [1,2,3],
    [4,5,6]
])

tab2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# matrice => ligne n et colonne m
#
#
# tab1 = np.array([ 1,2,3 ]) => les dimensions de cette matrice ( n , m ) ( 3, 1 )

# %%
tab1.shape
# Out:
# (3,)

# %%
tab1 = tab1.reshape((3,1))     # solution 1 
tab1 = np.reshape( tab1,(3,1)) # solution 2
tab1.shape
# essentiel de donner une valeur pour le nombre de colonne sur les vecteurs
# Out:
# (3, 1)
